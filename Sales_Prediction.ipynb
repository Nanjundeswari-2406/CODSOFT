# %% [markdown]
# <a href="https://colab.research.google.com/github/Nanjundeswari-2406/CODSOFT/blob/main/Sales_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import pandas as pd
import  matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Loading the dataset

# %%
df=pd.read_csv('/content/Advertising.csv')

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.shape
# Out:
# (200, 5)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
df['Sales'].value_counts()
# Out:
# 9.7     5
# 11.7    4
# 12.9    4
# 15.9    4
# 20.7    3
#        ..
# 17.0    1
# 18.3    1
# 22.3    1
# 14.0    1
# 25.5    1
# Name: Sales, Length: 121, dtype: int64

# %% [markdown]
# Data visualization

# %%
sns.countplot(x='Sales',data=df)
# Out:
# <Axes: xlabel='Sales', ylabel='count'>

# %%
df['TV'].hist()
# Out:
# <Axes: >

# %%
df['Radio'].hist()
# Out:
# <Axes: >

# %%
df['Newspaper'].hist()
# Out:
# <Axes: >

# %%
df['Sales'].hist()
# Out:
# <Axes: >

# %%
sns.pairplot(df,x_vars=['TV','Radio','Newspaper'],y_vars='Sales',kind='scatter')

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# Model Training

# %%
x=df.drop(columns=['Sales'])
y=df['Sales']
x_train, x_test, y_train, y_test= train_test_split(x,y,test_size=0.3,random_state=2)

# %%
print(x.shape, x_train.shape ,x_test.shape)
# Out:
# (200, 4) (140, 4) (60, 4)

# %%
print(x_train)
# Out:
#      Unnamed: 0     TV  Radio  Newspaper
# 28           29  248.8   27.1       22.9
# 133         134  219.8   33.5       45.1
# 94           95  107.4   14.0       10.9
# 42           43  293.6   27.7        1.8
# 169         170  284.3   10.6        6.4
# ..          ...    ...    ...        ...
# 43           44  206.9    8.4       26.4
# 22           23   13.2   15.9       49.6
# 72           73   26.8   33.0       19.3
# 15           16  195.4   47.7       52.9
# 168         169  215.4   23.6       57.6
#
# [140 rows x 4 columns]

# %%
print(y_train)
# Out:
# 28     18.9
# 133    19.6
# 94     11.5
# 42     20.7
# 169    15.0
#        ...
# 43     12.9
# 22      5.6
# 72      8.8
# 15     22.4
# 168    17.1
# Name: Sales, Length: 140, dtype: float64

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_train_prediction=model.predict(x_train)

# %%
print(x_train_prediction)
# Out:
# [19.65132275 19.42010699 10.6826541  21.64211218 17.94724953 10.50520313
#  18.5933678   6.49094354  4.02167952  9.11846139 10.70066005 10.7767671
#  15.4032636  10.04533766 12.73667997  7.06415147  4.75213627  9.90498851
#  14.37341596 18.56468977 23.23130907 23.34495458 14.59189355 12.49395831
#  17.10389519 21.04975821 17.39355387 10.29735383 24.27569736 15.9858161
#  18.5755543  10.52629148 15.4807454  19.3381945  13.92844138 21.98911577
#  15.49005472 23.59184609 18.21085959 14.12885423 15.34008545  6.86574191
#  19.42598834  8.45054902 21.60885414 10.41904239 15.206218   21.55413062
#  13.6984688  16.36177144  4.99923287 17.11272992 14.68210811 12.78593932
#  17.45038078 12.24641029 13.71137422 10.39312114  8.24623161 15.92834502
#  10.27176982 20.85923158 10.29664132 15.52086255 23.79817349  9.40322513
#  11.09108328 13.82180966 23.14610737 15.10579911 19.05940947  8.28081394
#   8.91451159 14.45853433 11.73459837 18.03740926  6.20799478  7.98214684
# ...

# %%
plt.plot(x_train_prediction)

# %%
y_pred = model.predict(x_test)

# %%
print(y_pred)
# Out:
# [13.9532874   9.66868515  6.8184482  15.17477774 18.17445759 15.71712804
#   7.57102926 20.49761622 13.19168021 17.33321225 11.14787534 19.48405747
#   9.21291503 10.79916797 13.87449153 12.82277648  9.32688188 18.03502362
#  16.4741683  18.82432455 16.92036691 16.04687481 12.02316254 12.14339122
#  14.87243899 12.08358743 15.49759505  8.08839314 16.76959963 13.87908137
#  16.20151428 17.08595853 13.05758661 13.02632284  8.91762832 11.01315087
#  21.97837505 19.89971271 15.98938391 20.23559933 21.12563546 17.17066585
#  21.13093152 15.04421578 19.66106778 18.74322737 17.58850441 10.34247317
#   9.60222257 13.00297864 12.59823575 14.39336676 17.46356839 16.99371718
#   8.55587416 17.10336367  9.13263193  4.15865759  7.67835429 24.67819442]

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print('Mean Squared Error:', mse)
print('R-squared:', r2)
# Out:
# Mean Squared Error: 5.029617654860843
# R-squared: 0.8021354391516504
